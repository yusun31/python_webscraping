# %% [markdown]
# ### 웹툰 이미지를 다운로드하여 로컬에 저장하기

# %%
import requests
import os

req_header_dict = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=552960&no=410&amp;weekday=fri'
}

img_url_list = [
    'https://image-comic.pstatic.net/webtoon/552960/410/20220113151757_90bb11af8a341a8bf8a8558fb3d3c121_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/552960/410/20220113151757_90bb11af8a341a8bf8a8558fb3d3c121_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/552960/410/20220113151757_90bb11af8a341a8bf8a8558fb3d3c121_IMAG01_3.jpg'
]

for img_url in img_url_list:
    res = requests.get(img_url, headers=req_header_dict)
    print(res.status_code)
    if res.ok:
        # binary data 가져올때 .content 속성사용
        img_data = res.content
        # url에서 파일명만 추출하기
        file_name = os.path.basename(img_url)
        file_name = 'data/' + file_name 
        
        # 서버에서 가져온 binary data를 file로 저장하기
        with open(file_name, 'wb') as file:
            print(f'Write to file {file_name} ({len(img_data):,}) bytes')
            file.write(img_data)
# Out:
# 200
# Write to file data/20220113151757_90bb11af8a341a8bf8a8558fb3d3c121_IMAG01_1.jpg (162,066) bytes
# 200
# Write to file data/20220113151757_90bb11af8a341a8bf8a8558fb3d3c121_IMAG01_2.jpg (215,640) bytes
# 200
# Write to file data/20220113151757_90bb11af8a341a8bf8a8558fb3d3c121_IMAG01_3.jpg (212,535) bytes

# %% [markdown]
# ### 웹툰의 특정회차의 모든 image 다운로드 하기
# * Attribute Selector를 사용하여 jpg 파일명들을 모두 추출하여 리스트에 저장하기

# %%
import requests
from bs4 import BeautifulSoup

main_url = 'https://comic.naver.com/webtoon/detail?titleId=764040&no=54&weekday=fri'
res = requests.get(main_url)

if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    img_tags = soup.select("img[src$='.jpg']") 
    print( len(img_tags), type(img_tags) )
    
    img_url_list = []
    for img_tag in img_tags:
        #print(type(img_tag), img_tag)
        img_url = img_tag['src']
        img_url_list.append(img_url)

print(len(img_url_list))
print(img_url_list[:4])
# Out:
# 72 <class 'bs4.element.ResultSet'>
# 72
# ['https://shared-comic.pstatic.net/thumb/webtoon/764040/thumbnail/thumbnail_IMAG04_8afc9026-2558-49e9-b675-93381d9ef009.jpg', 'https://image-comic.pstatic.net/webtoon/764040/54/20220127142619_b148e6dfbf0f74b0c384744f9e46035c_IMAG01_1.jpg', 'https://image-comic.pstatic.net/webtoon/764040/54/20220127142619_b148e6dfbf0f74b0c384744f9e46035c_IMAG01_2.jpg', 'https://image-comic.pstatic.net/webtoon/764040/54/20220127142619_b148e6dfbf0f74b0c384744f9e46035c_IMAG01_3.jpg']

# %%
# img 디렉토리 생성하기
import os

dir_path = 'img'

#img 디렉토리가 없으면
if not os.path.isdir(dir_path):
    os.mkdir(dir_path)

# %% [markdown]
# ### 디렉토리 생성하는 2가지 함수
# * os.mkdir() / osk.makedirs()
#  1. os.mkdir() 은 1개 폴더만 생성
#  2. os.makedirs() 는 a/b/c 처럼 하위 폴더를 생성

# %% [markdown]
# * 리스트를 순회하면서 image 다운로드 하기

# %%
for idx, img_url in enumerate(img_url_list, 1):
    #print(f'다운로드 번호 {idx} URL = {img_url}')
    req_header = {'referer':main_url}
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_name = os.path.basename(img_url)
        file_name = 'img/' + file_name
        with open(file_name, 'wb') as file:
            file.write(img_data)

# %%
# 파일들이 있는 디렉토리 삭제
import shutil
import os

dir_path = 'img'
#img 디렉토리가 있다면
if os.path.exists(dir_path):
    shutil.rmtree(dir_path)

# %% [markdown]
# #### 웹툰의 타이틀과 특정회차 url을 아규먼트 받아서 다운로드 하는 함수 구현하기

# %%
def download_image(title, round_url):
    import requests
    from bs4 import BeautifulSoup
    import os
    import shutil
    
    # img 폴더가 있으면 삭제하기
    dir_path = 'img'
    
    if os.path.exists(dir_path):
        shutil.rmtree(dir_path)
        
    #img 디렉토리가 없으면
    if not os.path.isdir(dir_path):
        #img\외모지상주의
        title_path = os.path.join(dir_path, title)
        print(title_path)
        os.makedirs(title_path)
    
    # img url 목록을 알아내기 위한 요청을 보내기
    res = requests.get(round_url)
    if res.ok:
        # 응답으로 받은 html텍스트를 파싱하기 위한 파서(BeautifulSoup)객체생성
        soup = BeautifulSoup(res.text, 'html.parser')
        # img태그 중에서 src 속성의 값이 .jpg로 끝나는 태그들만 선택하기
        img_tags = soup.select("img[src$='.jpg']") 
        print( len(img_tags), type(img_tags) )
        
        # 특정회차 url을 referer 헤더로 설정하기
        req_header = { 'referer':round_url }
        
        for idx, img_tag in enumerate(img_tags,1):
            #img 태그의 src 속성의 값을 추출하기
            print(f'------> 다운로드 번호 {idx}')
            img_url = img_tag['src']
            
            # jpg image 데이터 요청하기
            res_img = requests.get(img_url, headers=req_header)
            if res_img.ok:
                # image binary 데이터 가져오기
                img_data = res_img.content
                
                #img\외모지상주의\thumbnail_IMAG04_be987481-7e58-478d-ae1b-c33228ccc658.jpg
                file_name = title_path + '\\' + os.path.basename(img_url)
                
                with open(file_name, 'wb') as file:
                    print(f'{file_name} ({len(img_data)}) bytes')
                    file.write(img_data)

# %%
download_image('외모지상주의','https://comic.naver.com/webtoon/detail?titleId=641253&no=376&amp;weekday=fri')
# Out:
# img\외모지상주의
# 102 <class 'bs4.element.ResultSet'>
# ------> 다운로드 번호 1
# img\외모지상주의\thumbnail_IMAG04_be987481-7e58-478d-ae1b-c33228ccc658.jpg (15573) bytes
# ------> 다운로드 번호 2
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_1.jpg (208079) bytes
# ------> 다운로드 번호 3
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_2.jpg (205843) bytes
# ------> 다운로드 번호 4
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_3.jpg (169036) bytes
# ------> 다운로드 번호 5
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_4.jpg (161542) bytes
# ------> 다운로드 번호 6
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_5.jpg (120613) bytes
# ------> 다운로드 번호 7
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_6.jpg (88682) bytes
# ------> 다운로드 번호 8
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_7.jpg (136034) bytes
# ------> 다운로드 번호 9
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_8.jpg (132317) bytes
# ------> 다운로드 번호 10
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_9.jpg (171345) bytes
# ------> 다운로드 번호 11
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_10.jpg (155761) bytes
# ------> 다운로드 번호 12
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_11.jpg (104666) bytes
# ------> 다운로드 번호 13
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_12.jpg (151204) bytes
# ------> 다운로드 번호 14
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_13.jpg (229203) bytes
# ------> 다운로드 번호 15
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_14.jpg (95542) bytes
# ------> 다운로드 번호 16
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_15.jpg (102190) bytes
# ------> 다운로드 번호 17
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_16.jpg (111983) bytes
# ------> 다운로드 번호 18
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_17.jpg (109326) bytes
# ------> 다운로드 번호 19
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_18.jpg (87166) bytes
# ------> 다운로드 번호 20
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_19.jpg (129059) bytes
# ------> 다운로드 번호 21
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_20.jpg (99249) bytes
# ------> 다운로드 번호 22
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_21.jpg (124012) bytes
# ------> 다운로드 번호 23
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_22.jpg (125204) bytes
# ------> 다운로드 번호 24
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_23.jpg (85465) bytes
# ------> 다운로드 번호 25
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_24.jpg (123256) bytes
# ------> 다운로드 번호 26
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_25.jpg (146064) bytes
# ------> 다운로드 번호 27
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_26.jpg (91861) bytes
# ------> 다운로드 번호 28
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_27.jpg (151134) bytes
# ------> 다운로드 번호 29
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_28.jpg (158219) bytes
# ------> 다운로드 번호 30
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_29.jpg (89514) bytes
# ------> 다운로드 번호 31
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_30.jpg (117062) bytes
# ------> 다운로드 번호 32
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_31.jpg (199168) bytes
# ------> 다운로드 번호 33
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_32.jpg (98792) bytes
# ------> 다운로드 번호 34
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_33.jpg (104768) bytes
# ------> 다운로드 번호 35
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_34.jpg (204502) bytes
# ------> 다운로드 번호 36
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_35.jpg (166650) bytes
# ------> 다운로드 번호 37
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_36.jpg (174083) bytes
# ------> 다운로드 번호 38
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_37.jpg (136713) bytes
# ------> 다운로드 번호 39
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_38.jpg (92730) bytes
# ------> 다운로드 번호 40
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_39.jpg (105786) bytes
# ------> 다운로드 번호 41
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_40.jpg (121306) bytes
# ------> 다운로드 번호 42
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_41.jpg (94260) bytes
# ------> 다운로드 번호 43
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_42.jpg (60809) bytes
# ------> 다운로드 번호 44
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_43.jpg (166351) bytes
# ------> 다운로드 번호 45
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_44.jpg (155562) bytes
# ------> 다운로드 번호 46
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_45.jpg (136304) bytes
# ------> 다운로드 번호 47
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_46.jpg (104795) bytes
# ------> 다운로드 번호 48
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_47.jpg (99364) bytes
# ------> 다운로드 번호 49
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_48.jpg (160786) bytes
# ------> 다운로드 번호 50
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_49.jpg (149959) bytes
# ------> 다운로드 번호 51
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_50.jpg (125497) bytes
# ------> 다운로드 번호 52
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_51.jpg (78357) bytes
# ------> 다운로드 번호 53
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_52.jpg (172913) bytes
# ------> 다운로드 번호 54
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_53.jpg (130304) bytes
# ------> 다운로드 번호 55
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_54.jpg (129844) bytes
# ------> 다운로드 번호 56
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_55.jpg (108945) bytes
# ------> 다운로드 번호 57
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_56.jpg (132988) bytes
# ------> 다운로드 번호 58
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_57.jpg (110573) bytes
# ------> 다운로드 번호 59
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_58.jpg (116869) bytes
# ------> 다운로드 번호 60
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_59.jpg (173918) bytes
# ------> 다운로드 번호 61
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_60.jpg (150691) bytes
# ------> 다운로드 번호 62
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_61.jpg (153722) bytes
# ------> 다운로드 번호 63
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_62.jpg (99715) bytes
# ------> 다운로드 번호 64
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_63.jpg (106747) bytes
# ------> 다운로드 번호 65
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_64.jpg (105261) bytes
# ------> 다운로드 번호 66
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_65.jpg (117647) bytes
# ------> 다운로드 번호 67
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_66.jpg (171262) bytes
# ------> 다운로드 번호 68
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_67.jpg (121518) bytes
# ------> 다운로드 번호 69
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_68.jpg (188010) bytes
# ------> 다운로드 번호 70
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_69.jpg (148718) bytes
# ------> 다운로드 번호 71
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_70.jpg (161248) bytes
# ------> 다운로드 번호 72
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_71.jpg (121169) bytes
# ------> 다운로드 번호 73
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_72.jpg (229539) bytes
# ------> 다운로드 번호 74
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_73.jpg (180113) bytes
# ------> 다운로드 번호 75
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_74.jpg (150171) bytes
# ------> 다운로드 번호 76
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_75.jpg (141207) bytes
# ------> 다운로드 번호 77
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_76.jpg (119355) bytes
# ------> 다운로드 번호 78
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_77.jpg (133750) bytes
# ------> 다운로드 번호 79
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_78.jpg (103923) bytes
# ------> 다운로드 번호 80
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_79.jpg (107400) bytes
# ------> 다운로드 번호 81
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_80.jpg (120356) bytes
# ------> 다운로드 번호 82
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_81.jpg (147974) bytes
# ------> 다운로드 번호 83
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_82.jpg (178794) bytes
# ------> 다운로드 번호 84
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_83.jpg (120015) bytes
# ------> 다운로드 번호 85
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_84.jpg (128873) bytes
# ------> 다운로드 번호 86
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_85.jpg (64389) bytes
# ------> 다운로드 번호 87
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_86.jpg (137261) bytes
# ------> 다운로드 번호 88
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_87.jpg (78844) bytes
# ------> 다운로드 번호 89
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_88.jpg (161465) bytes
# ------> 다운로드 번호 90
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_89.jpg (144709) bytes
# ------> 다운로드 번호 91
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_90.jpg (140600) bytes
# ------> 다운로드 번호 92
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_91.jpg (109220) bytes
# ------> 다운로드 번호 93
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_92.jpg (89762) bytes
# ------> 다운로드 번호 94
# img\외모지상주의\20211223221603_26b09f8200b0269f8a4d2d4914fe15cf_IMAG01_93.jpg (118971) bytes
# ------> 다운로드 번호 95
# img\외모지상주의\641253_PC.jpg (19170) bytes
# ------> 다운로드 번호 96
# img\외모지상주의\thumbnail_202x120_cf5cf4ac-d6d6-4cb2-bb8b-d3a4398a4314.jpg (20934) bytes
# ------> 다운로드 번호 97
# img\외모지상주의\thumbnail_202x120_23c9a01a-ee03-48aa-a883-4f64515fb205.jpg (31457) bytes
# ------> 다운로드 번호 98
# img\외모지상주의\thumbnail_202x120_e93667d3-2410-4b26-b974-0f013ceca2d2.jpg (23222) bytes
# ------> 다운로드 번호 99
# img\외모지상주의\thumbnail_202x120_51e18012-17a9-4c52-a49d-802263ac3f4b.jpg (9604) bytes
# ------> 다운로드 번호 100
# img\외모지상주의\thumbnail_IMAG10_023d23be-91f9-46c5-a1ff-152d6238e892.jpg (8809) bytes
# ------> 다운로드 번호 101
# img\외모지상주의\title_thumbnail_20150407141027_t83x90.jpg (5965) bytes
# ------> 다운로드 번호 102
# img\외모지상주의\thumbnail_IMAG10_890975d8-f226-4e26-87b2-a002af9c9ebf.jpg (10595) bytes
